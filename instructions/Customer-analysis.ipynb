# %%
# %fs
ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/SampleNested.json</td><td>SampleNested.json</td><td>291</td><td>1756181682588</td></tr><tr><td>dbfs:/FileStore/tables/customer.csv</td><td>customer.csv</td><td>123654</td><td>1756134236057</td></tr><tr><td>dbfs:/FileStore/tables/product.json</td><td>product.json</td><td>198924</td><td>1756134552331</td></tr><tr><td>dbfs:/FileStore/tables/transactions_snappy.parquet</td><td>transactions_snappy.parquet</td><td>156864</td><td>1756134582464</td></tr></tbody></table></div>

# %%
df = spark.read.csv("/FileStore/tables/customer.csv", header = True, inferSchema = True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.types import * 
schema = StructType([
    StructField("customer_id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("email", StringType(), True),
    StructField("country", StringType(), True),
    StructField("customer_type", StringType(), True),
    StructField("registration_date", DateType(), True),
    StructField("age", IntegerType(), True),
    StructField("gender", StringType(), True),
    StructField("total_purchases", IntegerType(), True),
    StructField("ingestion_timestamp", TimestampType(), True)
]) 
df1 = spark.read.schema(schema).csv("/FileStore/tables/customer.csv", header = True)
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import col, column, when

df1 = df.filter(df["customer_type"] == "VIP")
df2 = df.filter(col("customer_type") == "Regular")
df3 = df.filter(column("customer_type") == "Premium")
df4 = df.filter(df.customer_type == "Premium")
df4 = df.filter((df.customer_type == "Premium") & (df.country == "USA"))
df6 = df.where((df.customer_type == "Premium") & (df.country == "USA"))
display(df6)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = df.withColumn("Salary", col("age")*1000)
display(df)

df2 = df.withColumn("Seniority", when(col("age") > 30, "Senior").otherwise("Junior"))

display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df3 = df2.withColumnRenamed("Seniority", "Is_Senior")
display(df3)
df4 = df3.drop("Is_Senior")
df5 = df3.drop("Is_Senior", "age", "gender")
display(df4)
df5.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df1 = df.select("age", "gender", "customer_type")
df2 = df.select("age", "gender", "customer_type", col("age") * 1000)
df3 = df.select("age", "gender", "customer_type", (col("age") * 1000).alias("Salary"))

display(df3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df1 = spark.read.json("/FileStore/tables/SampleNested.json")
df2 = df1.select("address.city", "address.state", "age", "name", "email")
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>state</th><th>age</th><th>name</th><th>email</th></tr></thead><tbody><tr><td>Anytown</td><td>CA</td><td>25</td><td>Alice</td><td>alice@example.com</td></tr><tr><td>Othertown</td><td>NY</td><td>30</td><td>Bob</td><td>bob@example.com</td></tr></tbody></table></div>

# %%
df1 = df.filter("customer_type == 'VIP'")
df2 = df.filter("customer_type == 'Regular'")

df3 = df1.union(df2)
df4 = df1.union(df2).union(df)

df5 = df4.distinct()
df6 = df4.select("customer_type").distinct()

display(df6)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_type</th></tr></thead><tbody><tr><td>VIP</td></tr><tr><td>Regular</td></tr><tr><td>Premium</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col
print(df.count())
df1 = df.na.drop()
print(df1.count())

df2 = df.filter(col("email").isNull())
display(df2)
df3 = df.na.fill("Unknown")
df4 = df.na.fill({"email": "Unknown", "age": 0})
df5 = df.fillna({"email": "Unknown", "age": 0})
display(df4.where("age == 0 "))
df.printSchema()

display(df.where(col("age").isNull()))
display(df5)

# %%
from pyspark.sql.functions import desc, asc, col
df1 = df.orderBy("age")
df3 = df.orderBy(desc("age"), desc("gender"))
df5 = df.sort(col("email").asc_nulls_first())
df5 = df.sort(col("email").asc_nulls_last())
display(df5)

# %%
from pyspark.sql.functions import sum, max, min, avg
df1 = df.groupBy("gender").count()
df2 = df.groupBy("gender" , "customer_type").count()
df3 = df.groupBy("gender").sum("age")
df4 = df.groupBy("gender").max("age")
df5 = df.groupBy("gender").min("age")
df6 = df.groupBy("gender").avg("age")
df7 = df.groupBy("gender").agg(sum("age").alias("Sum"), max("age").alias("Highest"), min("age").alias("Lowest"), avg("age").alias("Average"))
display(df7)

# %%
from pyspark.sql.functions import upper, lower, rtrim, ltrim, trim, regexp_replace, contains, length, concat_ws 
df1 = df.select(upper("country"))
df2 = df.select(lower("country"))
df3 = df.select(ltrim("country").alias("New_Country"), rtrim("country"), trim("country"))
df4 = df.select(regexp_replace(col("country"), "Unknown" , "Not Sure" ).alias("regex_replace_country"))

df5 = df.select("email", col("email").contains("customer"))
df7 = df.select("email", length("email"))
df8 = df.select(concat_ws("@@", "age", upper("country")).alias("concat_age_country")) # concat with seperator 
display(df8)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import * 
df1 = df.select("registration_date", year("registration_date"), month("registration_date"), dayofmonth("registration_date"))

df2 = df.select("registration_date" , dayofweek("registration_date"), weekofyear("registration_date"), dayofyear("registration_date"), quarter("registration_date"))

df3 = df.select("registration_date", date_add("registration_date", -30))
df4 = df.select("registration_date", date_sub("registration_date", 30))

# display(df3)
df5 = df.select("registration_date", date_format("registration_date", "MMMM dd , yyyy"))
df5 = df.select(current_date()).limit(1)

display(df5)

# %%
## time handling
df1 = df.select("ingestion_timestamp", year("ingestion_timestamp"), month("ingestion_timestamp"), dayofmonth("ingestion_timestamp"), hour("ingestion_timestamp"), minute("ingestion_timestamp"), second("ingestion_timestamp"))

df2 = df.select(current_timestamp())
df3 = df.select("ingestion_timestamp", date_format("ingestion_timestamp", "MMMM dd , yyyy hh:mm:ss"))
df4 = df.select("ingestion_timestamp", date_diff(current_timestamp(), "ingestion_timestamp").alias('diff'), date_format(current_timestamp(), "MMMM dd , yyyy hh:mm:ss") )

display(df4)

# %%
# df3.write.mode("overwrite").option("header", "True").csv("/FileStore/tables/Practice_Output/CSV/")

df3.write.mode("append").json("/FileStore/tables/Practice_Output/Json/")

df3.write.mode("overwrite").parquet("/FileStore/tables/Practice_Output/Parque/")

# %%
df3.write.mode("ignore").json("/FileStore/tables/Practice_Output/Json/") # if the folder is not empty , you not write anything

# %%
df3.write.mode("error").json("FileStore/tables/Practice_Output/Json/")
# if exists file in the folder, it will raise an error
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7981201553320503>, line 1
# ----> 1 df3.write.mode("error").json("FileStore/tables/Practice_Output/Json/")
#
# File /databricks/spark/python/pyspark/sql/connect/readwriter.py:740, in DataFrameWriter.json(self, path, mode, compression, dateFormat, timestampFormat, lineSep, encoding, ignoreNullFields)
#     731 self.mode(mode)
#     732 self._set_opts(
#     733     compression=compression,
#     734     dateFormat=dateFormat,
#    (...)
#     738     ignoreNullFields=ignoreNullFields,
#     739 )
# --> 740 self.format("json").save(path)
#
# File /databricks/spark/python/pyspark/sql/connect/readwriter.py:679, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#     677     self.format(format)
#     678 self._write.path = path
# --> 679 _, _, ei = self._spark.client.execute_command(
# ...

# %%
## write with partition 
df.write.mode("overwrite").option("header", "True").partitionBy("customer_type").csv("/FileStore/tables/Practice_Output/CSV_Partition/")

df.write.mode("overwrite").option("header", "True").partitionBy("country").json("/FileStore/tables/Practice_Output/Json_Partition/")

# df1 = spark.read.json("/FileStore/tables/Practice_Output/Json_Partition/country=Australia")

# display(df1) # result without the country column 

# df2 = spark.read.json("/FileStore/tables/Practice_Output/Json_Partition")
# display(df2) # result with the country column
